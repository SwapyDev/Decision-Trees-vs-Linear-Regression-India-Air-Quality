# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
#Read data 
df = pd.read_csv('city_day.csv')

# %%
#Display data
display(df)
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.head(5)
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
#Check duplicates (if existent)
df[df.duplicated(subset=['Date', 'City'])]
# Out:
# Empty DataFrame
# Columns: [City, Date, PM2.5, PM10, NO, NO2, NOx, NH3, CO, SO2, O3, Benzene, Toluene, Xylene, AQI, AQI_Bucket]
# Index: []

# %%
#Calculate AQI Buckets over time
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df_counts = df.groupby(['Year', 'AQI_Bucket']).size().unstack(fill_value=0)
df_counts.plot(kind='line', figsize=(20,6))

plt.title('AQI Buckets count over time')
plt.xlabel('Date')
plt.ylabel('Count of AQI Bucket')
plt.legend(title='AQI Bucket')
plt.show()

# %%
#See how frequently each quantity appears in the dataset

df_counts.plot(kind='hist', bins=30, title='AQI Buckets')
# Out:
# <Axes: title={'center': 'AQI Buckets'}, ylabel='Frequency'>

# %%
df_counts.plot(kind='kde', title='AQI Buckets')
# Out:
# <Axes: title={'center': 'AQI Buckets'}, ylabel='Density'>

# %%
df_pollutants = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
plt.figure(figsize=(8,6))

for pollutant in df_pollutants:
    plt.scatter(df[pollutant], df['AQI'], label= pollutant, alpha=0.6)

plt.title('Pollutant vs AQI')
plt.xlabel('Pollutants')
plt.ylabel('AQI')
plt.legend()
plt.show()

# %%
df_corr = df[['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']].corr()
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
df[df_pollutants]
# Out:
#        PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2      O3  \
# 0        NaN    NaN   0.92  18.22  17.15    NaN   0.92  27.64  133.36
# 1        NaN    NaN   0.97  15.69  16.46    NaN   0.97  24.55   34.06
# 2        NaN    NaN  17.40  19.30  29.70    NaN  17.40  29.07   30.70
# 3        NaN    NaN   1.70  18.48  17.97    NaN   1.70  18.59   36.08
# 4        NaN    NaN  22.10  21.42  37.76    NaN  22.10  39.33   39.31
# ...      ...    ...    ...    ...    ...    ...    ...    ...     ...
# 29526  15.02  50.94   7.68  25.06  19.54  12.47   0.47   8.55   23.30
# 29527  24.38  74.09   3.42  26.06  16.53  11.99   0.52  12.72   30.14
# 29528  22.91  65.73   3.45  29.53  18.33  10.71   0.48   8.42   30.96
# 29529  16.64  49.97   4.05  29.26  18.80  10.03   0.52   9.84   28.30
# 29530  15.00  66.00   0.40  26.85  14.05   5.20   0.59   2.10   17.05
#
#        Benzene  Toluene  Xylene
# 0         0.00     0.02    0.00
# 1         3.68     5.50    3.77
# ...

# %%
df_counts
# Out:
# AQI_Bucket  Good  Moderate  Poor  Satisfactory  Severe  Very Poor
# Year
# 2015          27       756   326           278     145        295
# 2016          80      1040   388           494     216        355
# 2017         110       956   378          1101     185        504
# 2018         183      2102   648          1825     409        557
# 2019         412      2490   754          2578     345        492
# 2020         529      1485   287          1948      38        134

# %%
#Count number of nulls per feature and display it in a table 
count_nulls = df.isnull().sum()
null_table = pd.DataFrame({'Column': count_nulls.index, 'Count': count_nulls.values})


display(null_table)
# Out:
#         Column  Count
# 0         City      0
# 1         Date      0
# 2        PM2.5   4598
# 3         PM10  11140
# 4           NO   3582
# 5          NO2   3585
# 6          NOx   4185
# 7          NH3  10328
# 8           CO   2059
# 9          SO2   3854
# 10          O3   4022
# 11     Benzene   5623
# 12     Toluene   8041
# 13      Xylene  18109
# 14         AQI   4681
# 15  AQI_Bucket   4681
# 16        Year      0

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#Calculate mean of each column to fill missing values
mean = df['PM2.5'].mean()
mean = int(mean)
df['PM2.5'] =df['PM2.5'].fillna(mean)

# %%
#Calculate mean of each column to fill missing values
mean = df['PM10'].mean()
mean = int(mean)
df['PM10'] =df['PM10'].fillna(mean)

# %%
#Calculate mean of each column to fill missing values
mean = df['CO'].mean()
mean = int(mean)
df['CO'] =df['CO'].fillna(mean)

# %%
#Calculate mean of each column to fill missing values
mean = df['O3'].mean()
mean = int(mean)
df['O3'] =df['O3'].fillna(mean)

# %%
#Calculate mean of each column to fill missing values
mean = df['NO2'].mean()
mean = int(mean)
df['NO2'] =df['NO2'].fillna(mean)

# %%
#Calculate mean of each column to fill missing values
mean = df['SO2'].mean()
mean = int(mean)
df['SO2'] =df['SO2'].fillna(mean)

# %%
#Calculate mean of each column to fill missing values
mean = df['NH3'].mean()
mean = int(mean)
df['NH3'] =df['NH3'].fillna(mean)

# %%
#Calculate mean of each column to fill missing values
mean = df['AQI'].mean()
mean = int(mean)
df['AQI'] =df['AQI'].fillna(mean)

# %%
count_nulls = df.isnull().sum()
null_table = pd.DataFrame({'Column': count_nulls.index, 'Count': count_nulls.values})
display(null_table)
# Out:
#         Column  Count
# 0         City      0
# 1         Date      0
# 2        PM2.5      0
# 3         PM10      0
# 4           NO   3582
# 5          NO2      0
# 6          NOx   4185
# 7          NH3      0
# 8           CO      0
# 9          SO2      0
# 10          O3      0
# 11     Benzene   5623
# 12     Toluene   8041
# 13      Xylene  18109
# 14         AQI      0
# 15  AQI_Bucket   4681
# 16        Year      0

# %%
#Drop unnecesary rows 
train_df = df.drop(['City', 'Date', 'NO', 'NOx', 'Benzene', 'Toluene', 'Xylene', 'AQI_Bucket'], axis=1)

# %%
#Dataset for training
train_df.head()
# Out:
#    PM2.5   PM10    NO2   NH3     CO    SO2      O3    AQI  Year
# 0   67.0  118.0  18.22  23.0   0.92  27.64  133.36  166.0  2015
# 1   67.0  118.0  15.69  23.0   0.97  24.55   34.06  166.0  2015
# 2   67.0  118.0  19.30  23.0  17.40  29.07   30.70  166.0  2015
# 3   67.0  118.0  18.48  23.0   1.70  18.59   36.08  166.0  2015
# 4   67.0  118.0  21.42  23.0  22.10  39.33   39.31  166.0  2015

# %%
#Initialize x_train
x = train_df[["PM2.5", "PM10", "NO2", 'NH3', 'CO','SO2','O3']]
x
# Out:
#        PM2.5    PM10    NO2    NH3     CO    SO2      O3
# 0      67.00  118.00  18.22  23.00   0.92  27.64  133.36
# 1      67.00  118.00  15.69  23.00   0.97  24.55   34.06
# 2      67.00  118.00  19.30  23.00  17.40  29.07   30.70
# 3      67.00  118.00  18.48  23.00   1.70  18.59   36.08
# 4      67.00  118.00  21.42  23.00  22.10  39.33   39.31
# ...      ...     ...    ...    ...    ...    ...     ...
# 29526  15.02   50.94  25.06  12.47   0.47   8.55   23.30
# 29527  24.38   74.09  26.06  11.99   0.52  12.72   30.14
# 29528  22.91   65.73  29.53  10.71   0.48   8.42   30.96
# 29529  16.64   49.97  29.26  10.03   0.52   9.84   28.30
# 29530  15.00   66.00  26.85   5.20   0.59   2.10   17.05
#
# [29531 rows x 7 columns]

# %%
#Initialize y
y = train_df[['AQI']]
y
# Out:
#          AQI
# 0      166.0
# 1      166.0
# 2      166.0
# 3      166.0
# 4      166.0
# ...      ...
# 29526   41.0
# 29527   70.0
# 29528   68.0
# 29529   54.0
# 29530   50.0
#
# [29531 rows x 1 columns]

# %%
#Split dataset into train variables and test variables
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
#Scale the data
scaler = StandardScaler().fit(x_train, x_test)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
#Initialize linear regression model
linear_reg = LinearRegression()

# %%
model = linear_reg.fit(x_train, y_train)
yhat = model.predict(x_test)
accuracy = model.score(x_train, y_train)
print(f'Score: {accuracy: .4f}')
# Out:
# Score:  0.7894

# %%
#Initialize decision tree 
from sklearn.tree import DecisionTreeRegressor
decision_tree = DecisionTreeRegressor()

# %%
model = decision_tree.fit(x_train, y_train)
y_hat = model.predict(x_test)
accuracy = model.score(x_train, y_train)
print(f'Score: {accuracy: 4f}')
# Out:
# Score:  0.999052
